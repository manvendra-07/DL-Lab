# %% [markdown]
# ## Importing the required libraries

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
import seaborn as sns
import tensorflow.keras.optimizers as optimizers
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Import the dataset

# %%
bodyfat = pd.read_csv('bodyfat.csv')
bodyfat.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %% [markdown]
# ## Scaling the data using MinMaxScaler

# %%
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(bodyfat)
bodyfat_scaled = pd.DataFrame(scaled_features, index=bodyfat.index, columns=bodyfat.columns)
bodyfat_scaled.head()
# Out:
#     Density   BodyFat       Age    Weight    Height      Neck     Chest  \
# 0  0.665496  0.258947  0.016949  0.146127  0.792746  0.253731  0.242531
# 1  0.792801  0.128421  0.000000  0.223789  0.886010  0.368159  0.251318
# 2  0.407375  0.532632  0.000000  0.145105  0.761658  0.144279  0.289982
# 3  0.703248  0.218947  0.067797  0.270795  0.886010  0.313433  0.395431
# 4  0.342406  0.604211  0.033898  0.268751  0.865285  0.164179  0.316344
#
#     Abdomen       Hip     Thigh      Knee     Ankle    Biceps   Forearm  \
# 0  0.200762  0.151515  0.294264  0.267081  0.189189  0.356436  0.460432
# 1  0.172808  0.218501  0.286783  0.267081  0.290541  0.282178  0.568345
# 2  0.235070  0.226475  0.309227  0.366460  0.331081  0.198020  0.302158
# 3  0.216010  0.258373  0.321696  0.267081  0.250000  0.376238  0.604317
# 4  0.388818  0.269537  0.399002  0.571429  0.331081  0.366337  0.482014
#
#       Wrist
# 0  0.232143
# 1  0.428571
# 2  0.142857
# 3  0.428571
# 4  0.339286

# %% [markdown]
# ## Splitting the dataset

# %%
Y = bodyfat_scaled['BodyFat']
X = bodyfat_scaled.drop(columns = 'BodyFat', axis = 1)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.15, random_state=42)

# %% [markdown]
# ## Storing Learning Rates, Epochs, Activations and Regularizations to train

# %%
learning_rate = [1, 0.3, 0.1, 0.01,0.03,0.001,0.0001,0.00001]
epochs = [10,20,30,40]
activations = ['sigmoid', 'relu']
regularizations = [None,'l1', 'l2']
train_values, test_values, loss_values, val_loss_values = [], [], [], []

# %% [markdown]
# ## 1 - Hidden Layer Model

# %%
def One_Layer_Model(epochs, lr, reg, activation):
  train_values = {}
  test_values = {}
  loss = {}
  val_loss = {}
  if reg == None :
      model = tf.keras.Sequential()
      model.add(tf.keras.layers.InputLayer(input_shape = 14 , name = 'InputLayer'))
      model.add(tf.keras.layers.Dense(128, activation = activation , name="HiddenLayer1"))
      model.add(tf.keras.layers.Dense(1, activation = 'linear', name='OutputLayer'))
      
      model.compile(loss="mean_squared_error", optimizer=optimizers.Adam(learning_rate = lr), metrics=[tf.keras.metrics.RootMeanSquaredError(name = 'rmse')])

      history = model.fit(X_train, Y_train, batch_size = 8, epochs=epochs, validation_split=0.15, verbose = 0)

      test = model.evaluate(X_test, Y_test, verbose = 2)

      train_values['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['rmse']   
      test_values['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = test[1]
      loss['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['loss']
      val_loss['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['val_loss']
  
  elif reg == 'l1' or reg == 'l2':
      model = tf.keras.Sequential()
      model.add(tf.keras.layers.InputLayer(input_shape = (14,), name = 'InputLayer'))
      model.add(tf.keras.layers.Dense(128, activation = activation, name="HiddenLayer1", kernel_regularizer = reg))
      model.add(tf.keras.layers.Dense(1, activation = 'linear', name='OutputLayer'))
      
      model.compile(loss="mean_squared_error", metrics=[tf.keras.metrics.RootMeanSquaredError(name = 'rmse')])

      history = model.fit(X_train, Y_train, epochs=epochs, validation_split=0.15, verbose = 0)

      test = model.evaluate(X_test, Y_test, verbose = 2)

      train_values['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['rmse']   
      test_values['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = test[1]
      loss['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['loss']
      val_loss['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['val_loss']

  return train_values, test_values, loss, val_loss

# %% [markdown]
# ## Training Using No Regularization and L1, L2 Regularization

# %%
for lr in learning_rate:
  for epoch in epochs:
    for activation in activations:
      for reg in regularizations:
        train_val , test_val, loss, val_loss = One_Layer_Model(epochs = epoch, lr = lr, activation = activation, reg = reg)
        train_values.append(train_val)
        test_values.append(test_val)
        loss_values.append(loss)
        val_loss_values.append(val_loss)
# Out:
# 2/2 - 0s - loss: 0.0184 - rmse: 0.1358 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.8771 - rmse: 0.1401 - 23ms/epoch - 12ms/step
# 2/2 - 0s - loss: 0.1334 - rmse: 0.1177 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0170 - rmse: 0.1302 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.9489 - rmse: 0.1190 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.1441 - rmse: 0.0824 - 19ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.0189 - rmse: 0.1373 - 20ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.4022 - rmse: 0.1230 - 28ms/epoch - 14ms/step
# 2/2 - 0s - loss: 0.0489 - rmse: 0.0951 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0159 - rmse: 0.1260 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.3158 - rmse: 0.0819 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0604 - rmse: 0.0687 - 20ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.0177 - rmse: 0.1329 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0434 - rmse: 0.1355 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0293 - rmse: 0.0859 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0187 - rmse: 0.1367 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0711 - rmse: 0.1106 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0311 - rmse: 0.0627 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0280 - rmse: 0.1674 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0262 - rmse: 0.1311 - 19ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.0193 - rmse: 0.0917 - 36ms/epoch - 18ms/step
# 2/2 - 0s - loss: 0.0194 - rmse: 0.1393 - 20ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.0340 - rmse: 0.0905 - 20ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.0264 - rmse: 0.0890 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0181 - rmse: 0.1346 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.9366 - rmse: 0.1442 - 19ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.1377 - rmse: 0.1192 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0088 - rmse: 0.0938 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.9560 - rmse: 0.1519 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.1387 - rmse: 0.0891 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0213 - rmse: 0.1458 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.3096 - rmse: 0.1703 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0549 - rmse: 0.0921 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0053 - rmse: 0.0731 - 32ms/epoch - 16ms/step
# 2/2 - 0s - loss: 0.3595 - rmse: 0.1229 - 203ms/epoch - 102ms/step
# 2/2 - 0s - loss: 0.0563 - rmse: 0.0782 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0198 - rmse: 0.1408 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0457 - rmse: 0.1299 - 19ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.0284 - rmse: 0.0919 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0041 - rmse: 0.0640 - 20ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.0876 - rmse: 0.0911 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0381 - rmse: 0.0838 - 20ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.0200 - rmse: 0.1415 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0261 - rmse: 0.1304 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0209 - rmse: 0.1096 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 2.4299e-04 - rmse: 0.0156 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0320 - rmse: 0.0890 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0222 - rmse: 0.0573 - 35ms/epoch - 17ms/step
# 2/2 - 0s - loss: 0.0188 - rmse: 0.1370 - 195ms/epoch - 98ms/step
# 2/2 - 0s - loss: 1.0304 - rmse: 0.1173 - 19ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.1880 - rmse: 0.1823 - 22ms/epoch - 11ms/step
# 2/2 - 0s - loss: 0.
- 20ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.0012 - rmse: 0.0340 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0636 - rmse: 0.1460 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0364 - rmse: 0.1417 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 6.6456e-04 - rmse: 0.0258 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0672 - rmse: 0.0866 - 21ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.0303 - rmse: 0.0526 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0031 - rmse: 0.0552 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0337 - rmse: 0.1562 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0170 - rmse: 0.0904 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0013 - rmse: 0.0364 - 175ms/epoch - 88ms/step
# 2/2 - 0s - loss: 0.0342 - rmse: 0.0924 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0221 - rmse: 0.0628 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0134 - rmse: 0.1158 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 1.0613 - rmse: 0.1242 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.1247 - rmse: 0.1208 - 19ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.0208 - rmse: 0.1443 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.8451 - rmse: 0.1064 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.1323 - rmse: 0.0993 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0179 - rmse: 0.1338 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.3499 - rmse: 0.1600 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0675 - rmse: 0.1140 - 20ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.0074 - rmse: 0.0863 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.2926 - rmse: 0.0985 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0580 - rmse: 0.0891 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0112 - rmse: 0.1057 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0707 - rmse: 0.1786 - 20ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.0334 - rmse: 0.1289 - 19ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.0057 - rmse: 0.0758 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0611 - rmse: 0.1026 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0423 - rmse: 0.0901 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0098 - rmse: 0.0988 - 27ms/epoch - 13ms/step
# 2/2 - 0s - loss: 0.0386 - rmse: 0.1698 - 22ms/epoch - 11ms/step
# 2/2 - 0s - loss: 0.0162 - rmse: 0.0876 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0065 - rmse: 0.0806 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0340 - rmse: 0.1013 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0211 - rmse: 0.0464 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0242 - rmse: 0.1555 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.8406 - rmse: 0.1357 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1186 - rmse: 0.1116 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0817 - rmse: 0.2859 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.9225 - rmse: 0.1018 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1250 - rmse: 0.0948 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0421 - rmse: 0.2053 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.3729 - rmse: 0.1421 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0687 - rmse: 0.1239 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.1181 - rmse: 0.3437 - 19ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.3387 - rmse: 0.0852 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0626 - rmse: 0.0941 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0227 - rmse: 0.1506 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0503 - rmse: 0.1397 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0272 - rmse: 0.1079 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0218 - rmse: 0.1475 - 29ms/epoch - 14ms/step
# 2/2 - 0s - loss: 0.0709 - rmse: 0.1163 - 33ms/epoch - 17ms/step
# 2/2 - 0s - loss: 0.0348 - rmse: 0.0546 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0192 - rmse: 0.1385 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0274 - rmse: 0.1355 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0194 - rmse: 0.1016 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0142 - rmse: 0.1194 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0325 - rmse: 0.0923 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0262 - rmse: 0.0864 - 17ms/epoch - 9ms/step

# %% [markdown]
# ## 2 - Hidden Layers Model

# %%
def Two_Layer_Model(epochs, lr, reg, activation):
  train_values = {}
  test_values = {}
  loss = {}
  val_loss = {}
  if reg == None :
      model = tf.keras.Sequential()
      model.add(tf.keras.layers.InputLayer(input_shape = 14 , name = 'InputLayer'))
      model.add(tf.keras.layers.Dense(128, activation = activation , name="HiddenLayer1"))
      model.add(tf.keras.layers.Dense(64, activation = activation , name="HiddenLayer2"))
      model.add(tf.keras.layers.Dense(1, activation = 'linear', name='OutputLayer'))
      
      model.compile(loss="mean_squared_error", optimizer=optimizers.Adam(learning_rate = lr), metrics=[tf.keras.metrics.RootMeanSquaredError(name = 'rmse')])

      history = model.fit(X_train, Y_train, batch_size = 8, epochs=epochs, validation_split=0.15, verbose = 0)

      test = model.evaluate(X_test, Y_test, verbose = 2)

      train_values['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['rmse']   
      test_values['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = test[1]
      loss['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['loss']
      val_loss['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['val_loss']

  elif reg == 'l1' or reg == 'l2':
      model = tf.keras.Sequential()
      model.add(tf.keras.layers.InputLayer(input_shape = (14,), name = 'InputLayer'))
      model.add(tf.keras.layers.Dense(128, activation = activation, name="HiddenLayer1", kernel_regularizer = reg))
      model.add(tf.keras.layers.Dense(64, activation = activation, name="HiddenLayer2", kernel_regularizer = reg))
      model.add(tf.keras.layers.Dense(1, activation = 'linear', name='OutputLayer'))
      
      model.compile(loss="mean_squared_error", metrics=[tf.keras.metrics.RootMeanSquaredError(name = 'rmse')])

      history = model.fit(X_train, Y_train, epochs=epochs, validation_split=0.15, verbose = 0)

      test = model.evaluate(X_test, Y_test, verbose = 2)

      train_values['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['rmse']   
      test_values['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = test[1]
      loss['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['loss']
      val_loss['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['val_loss']

  return train_values, test_values, loss, val_loss

# %% [markdown]
# ## Training Using No Regularization and L1, L2 Regularization

# %%
for lr in learning_rate:
  for epoch in epochs:
    for activation in activations:
      for reg in regularizations:
        train_val , test_val, loss, val_loss = Two_Layer_Model(epochs = epoch, lr = lr, activation = activation, reg = reg)
        train_values.append(train_val)
        test_values.append(test_val)
        loss_values.append(loss)
        val_loss_values.append(val_loss)
# Out:
# 2/2 - 0s - loss: 0.1379 - rmse: 0.3714 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 4.5277 - rmse: 0.1342 - 30ms/epoch - 15ms/step
# 2/2 - 0s - loss: 0.6901 - rmse: 0.1304 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0205 - rmse: 0.1431 - 24ms/epoch - 12ms/step
# 2/2 - 0s - loss: 3.7930 - rmse: 0.1336 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.4027 - rmse: 0.0761 - 23ms/epoch - 12ms/step
# 2/2 - 0s - loss: 0.0177 - rmse: 0.1332 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 1.2199 - rmse: 0.1431 - 22ms/epoch - 11ms/step
# 2/2 - 0s - loss: 0.3241 - rmse: 0.1322 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0175 - rmse: 0.1324 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.9315 - rmse: 0.1317 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.1153 - rmse: 0.0756 - 25ms/epoch - 13ms/step
# 2/2 - 0s - loss: 0.0186 - rmse: 0.1363 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.1031 - rmse: 0.1451 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1681 - rmse: 0.1637 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0213 - rmse: 0.1461 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0987 - rmse: 0.1339 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0571 - rmse: 0.1407 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0490 - rmse: 0.2213 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0674 - rmse: 0.1375 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1289 - rmse: 0.1650 - 197ms/epoch - 98ms/step
# 2/2 - 0s - loss: 0.0175 - rmse: 0.1323 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0689 - rmse: 0.1364 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0228 - rmse: 0.0529 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0191 - rmse: 0.1382 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 3.6045 - rmse: 0.1312 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.6671 - rmse: 0.2617 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0097 - rmse: 0.0985 - 28ms/epoch - 14ms/step
# 2/2 - 0s - loss: 3.7328 - rmse: 0.1101 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.4158 - rmse: 0.1182 - 190ms/epoch - 95ms/step
# 2/2 - 0s - loss: 0.0241 - rmse: 0.1553 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.9374 - rmse: 0.1660 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.2479 - rmse: 0.1294 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0177 - rmse: 0.1332 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.9672 - rmse: 0.1322 - 21ms/epoch - 11ms/step
# 2/2 - 0s - loss: 0.1364 - rmse: 0.1008 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.
- 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 4.3492 - rmse: 0.1552 - 19ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.6306 - rmse: 0.1429 - 21ms/epoch - 11ms/step
# 2/2 - 0s - loss: 0.0025 - rmse: 0.0499 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 3.6760 - rmse: 0.1164 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.3853 - rmse: 0.0858 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0120 - rmse: 0.1095 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 1.0437 - rmse: 0.1305 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.2508 - rmse: 0.1353 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 9.6359e-04 - rmse: 0.0310 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.9093 - rmse: 0.1202 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.1090 - rmse: 0.0703 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0037 - rmse: 0.0612 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0782 - rmse: 0.1309 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.1231 - rmse: 0.1298 - 19ms/epoch - 10ms/step
# 2/2 - 0s - loss: 9.0028e-04 - rmse: 0.0300 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0976 - rmse: 0.1397 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0514 - rmse: 0.0643 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0049 - rmse: 0.0702 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0696 - rmse: 0.1305 - 30ms/epoch - 15ms/step
# 2/2 - 0s - loss: 0.1704 - rmse: 0.2143 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 9.2556e-04 - rmse: 0.0304 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0700 - rmse: 0.1439 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0271 - rmse: 0.0561 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0192 - rmse: 0.1384 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 4.6424 - rmse: 0.1558 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.6282 - rmse: 0.2174 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0100 - rmse: 0.1001 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 3.6779 - rmse: 0.1025 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.3921 - rmse: 0.0880 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0168 - rmse: 0.1296 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 1.3301 - rmse: 0.1700 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.3255 - rmse: 0.1268 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0068 - rmse: 0.0822 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.9187 - rmse: 0.1380 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1250 - rmse: 0.1105 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0137 - rmse: 0.1171 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0909 - rmse: 0.1646 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1734 - rmse: 0.1993 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0043 - rmse: 0.0654 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0928 - rmse: 0.1318 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0451 - rmse: 0.0632 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0153 - rmse: 0.1238 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0654 - rmse: 0.1303 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1376 - rmse: 0.1277 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0033 - rmse: 0.0572 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0686 - rmse: 0.1383 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0288 - rmse: 0.0618 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1130 - rmse: 0.3362 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 3.7910 - rmse: 0.1313 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.6791 - rmse: 0.1500 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0340 - rmse: 0.1845 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 3.6249 - rmse: 0.1054 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.4377 - rmse: 0.1024 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0185 - rmse: 0.1362 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 1.0200 - rmse: 0.1601 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.3533 - rmse: 0.1628 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0614 - rmse: 0.2477 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.9279 - rmse: 0.1384 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.1335 - rmse: 0.0885 - 23ms/epoch - 12ms/step
# 2/2 - 0s - loss: 0.6344 - rmse: 0.7965 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1468 - rmse: 0.1881 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1883 - rmse: 0.1477 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0107 - rmse: 0.1036 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0926 - rmse: 0.1363 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0471 - rmse: 0.0979 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1567 - rmse: 0.3958 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0716 - rmse: 0.1521 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0881 - rmse: 0.1440 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0152 - rmse: 0.1233 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0706 - rmse: 0.1436 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0238 - rmse: 0.0532 - 18ms/epoch - 9ms/step

# %% [markdown]
# ## 3 - Hidden Layers Model

# %%
def Three_Layer_Model(epochs, lr, reg, activation):
  train_values = {}
  test_values = {}
  loss = {}
  val_loss = {}
  if reg == None :
      model = tf.keras.Sequential()
      model.add(tf.keras.layers.InputLayer(input_shape = 14 , name = 'InputLayer'))
      model.add(tf.keras.layers.Dense(128, activation = activation , name="HiddenLayer1"))
      model.add(tf.keras.layers.Dense(64, activation = activation , name="HiddenLayer2"))
      model.add(tf.keras.layers.Dense(32, activation = activation , name="HiddenLayer3"))
      model.add(tf.keras.layers.Dense(1, activation = 'linear', name='OutputLayer'))
      
      model.compile(loss="mean_squared_error", optimizer=optimizers.Adam(learning_rate = lr), metrics=[tf.keras.metrics.RootMeanSquaredError(name = 'rmse')])

      history = model.fit(X_train, Y_train, batch_size = 8, epochs=epochs, validation_split=0.15, verbose = 0)

      test = model.evaluate(X_test, Y_test, verbose = 2)

      train_values['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['rmse']   
      test_values['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = test[1]
      loss['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['loss']
      val_loss['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['val_loss']

  elif reg == 'l1' or reg == 'l2':
      model = tf.keras.Sequential()
      model.add(tf.keras.layers.InputLayer(input_shape = (14,), name = 'InputLayer'))
      model.add(tf.keras.layers.Dense(128, activation = activation, name="HiddenLayer1", kernel_regularizer = reg))
      model.add(tf.keras.layers.Dense(64, activation = activation, name="HiddenLayer2", kernel_regularizer = reg))
      model.add(tf.keras.layers.Dense(64, activation = activation, name="HiddenLayer3", kernel_regularizer = reg))
      model.add(tf.keras.layers.Dense(1, activation = 'linear', name='OutputLayer'))
      model.compile(loss="mean_squared_error", metrics=[tf.keras.metrics.RootMeanSquaredError(name = 'rmse')])

      history = model.fit(X_train, Y_train, epochs=epochs, validation_split=0.15, verbose = 0)

      test = model.evaluate(X_test, Y_test, verbose = 2)

      train_values['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['rmse']   
      test_values['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = test[1]
      loss['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['loss']
      val_loss['HL : 3, reg : ' + str(reg) + ', lr : ' + str(lr) + ', epochs : '+ str(epochs) + ', activation : ' + activation] = history.history['val_loss']

  return train_values, test_values, loss, val_loss

# %% [markdown]
# ## Training Using No Regularization and L1, L2 Regularization

# %%
for lr in learning_rate:
  for epoch in epochs:
    for activation in activations:
      for reg in regularizations:
        train_val , test_val, loss, val_loss = Three_Layer_Model(epochs = epoch, lr = lr, activation = activation, reg = reg)
        train_values.append(train_val)
        test_values.append(test_val)
        loss_values.append(loss)
        val_loss_values.append(val_loss)
# Out:
# 2/2 - 0s - loss: 0.0537 - rmse: 0.2317 - 20ms/epoch - 10ms/step
# 2/2 - 0s - loss: 5.6885 - rmse: 0.1419 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.6450 - rmse: 0.1682 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 20.9539 - rmse: 4.5775 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 5.7336 - rmse: 0.1189 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.6399 - rmse: 0.1021 - 55ms/epoch - 27ms/step
# 2/2 - 0s - loss: 0.0888 - rmse: 0.2980 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 1.5935 - rmse: 0.1459 - 19ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.2533 - rmse: 0.1322 - 22ms/epoch - 11ms/step
# 2/2 - 0s - loss: 20.3779 - rmse: 4.5142 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 1.6427 - rmse: 0.1318 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1862 - rmse: 0.0868 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0170 - rmse: 0.1305 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.2331 - rmse: 0.1654 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.1181 - rmse: 0.1908 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0171 - rmse: 0.1308 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.1892 - rmse: 0.1353 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0667 - rmse: 0.1120 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0578 - rmse: 0.2404 - 21ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.1070 - rmse: 0.1550 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0681 - rmse: 0.1302 - 19ms/epoch - 10ms/step
# 2/2 - 0s - loss: 15.7424 - rmse: 3.9677 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0890 - rmse: 0.1368 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0295 - rmse: 0.0621 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0190 - rmse: 0.1380 - 22ms/epoch - 11ms/step
# 2/2 - 0s - loss: 5.7610 - rmse: 0.1335 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.6585 - rmse: 0.1374 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.3454 - rmse: 0.5877 - 24ms/epoch - 12ms/step
# 2/2 - 0s - loss: 5.6753 - rmse: 0.1209 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.6603 - rmse: 0.0928 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.
- 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0276 - rmse: 0.0683 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0177 - rmse: 0.1329 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 5.6990 - rmse: 0.1373 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.6862 - rmse: 0.1359 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0019 - rmse: 0.0440 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 5.7031 - rmse: 0.1260 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.6243 - rmse: 0.1016 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0095 - rmse: 0.0976 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 1.7185 - rmse: 0.1531 - 20ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.3379 - rmse: 0.1495 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0020 - rmse: 0.0450 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 1.6210 - rmse: 0.1324 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1921 - rmse: 0.0801 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0049 - rmse: 0.0697 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.2713 - rmse: 0.1760 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1173 - rmse: 0.1515 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 6.4119e-04 - rmse: 0.0253 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.1827 - rmse: 0.1382 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0615 - rmse: 0.0960 - 19ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.0021 - rmse: 0.0453 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0947 - rmse: 0.1574 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0685 - rmse: 0.1302 - 19ms/epoch - 10ms/step
# 2/2 - 0s - loss: 6.1944e-04 - rmse: 0.0249 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0892 - rmse: 0.1367 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0304 - rmse: 0.0655 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0182 - rmse: 0.1348 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 5.9225 - rmse: 0.1326 - 34ms/epoch - 17ms/step
# 2/2 - 0s - loss: 0.6861 - rmse: 0.1348 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0105 - rmse: 0.1022 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 5.7586 - rmse: 0.1223 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.6143 - rmse: 0.0836 - 27ms/epoch - 13ms/step
# 2/2 - 0s - loss: 0.0185 - rmse: 0.1361 - 19ms/epoch - 9ms/step
# 2/2 - 0s - loss: 1.7199 - rmse: 0.1307 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.2610 - rmse: 0.1411 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0070 - rmse: 0.0839 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 1.6196 - rmse: 0.1324 - 22ms/epoch - 11ms/step
# 2/2 - 0s - loss: 0.2199 - rmse: 0.0690 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0194 - rmse: 0.1392 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.2063 - rmse: 0.1489 - 19ms/epoch - 10ms/step
# 2/2 - 0s - loss: 0.1452 - rmse: 0.1792 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0033 - rmse: 0.0578 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1817 - rmse: 0.1377 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0549 - rmse: 0.0753 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0174 - rmse: 0.1319 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0857 - rmse: 0.1321 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0599 - rmse: 0.1518 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0023 - rmse: 0.0478 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0882 - rmse: 0.1351 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0331 - rmse: 0.0793 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 3.0184 - rmse: 1.7373 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 5.6497 - rmse: 0.1309 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.7678 - rmse: 0.1684 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0772 - rmse: 0.2779 - 20ms/epoch - 10ms/step
# 2/2 - 0s - loss: 5.6635 - rmse: 0.1265 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.6156 - rmse: 0.0913 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0245 - rmse: 0.1564 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 1.8590 - rmse: 0.1530 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.3122 - rmse: 0.1337 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0138 - rmse: 0.1177 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 1.6361 - rmse: 0.1366 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1860 - rmse: 0.0905 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.4864 - rmse: 0.6974 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.2187 - rmse: 0.1423 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1895 - rmse: 0.1793 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0116 - rmse: 0.1077 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.1819 - rmse: 0.1410 - 17ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.0475 - rmse: 0.0738 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.1515 - rmse: 0.3892 - 18ms/epoch - 9ms/step
# 2/2 - 0s - loss: 0.1072 - rmse: 0.1803 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0559 - rmse: 0.1334 - 17ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0105 - rmse: 0.1026 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0893 - rmse: 0.1371 - 16ms/epoch - 8ms/step
# 2/2 - 0s - loss: 0.0259 - rmse: 0.0795 - 17ms/epoch - 8ms/step

# %% [markdown]
# ## Obtaining Minimum Test RMSE

# %%
val = []
for value in test_values:
  val.append(list(value.values()))
val.sort()
min = val[0][0]
print(min)
# Out:
# 0.01409811433404684

# %% [markdown]
# ## Obtaining Index of Minimum Test RMSE

# %%
pos = ""
for test_value in test_values:
  for key, value in test_value.items():
      if value == min:
        pos = key
        break

# %%
print(pos)
# Out:
# HL : 3, reg : None, lr : 0.01, epochs : 30, activation : relu
