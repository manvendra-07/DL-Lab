# %% [markdown]
# <a href="https://colab.research.google.com/github/manvendra-07/DL-Lab/blob/main/Week%206/200968146_DL_Week6_Ex2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing the Required Libraries

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Preparing the data

# %% [markdown]
# - **Importing the dataset**

# %%
test_set = pd.read_csv('Google_Stock_Price_Test.csv')
train_set = pd.read_csv('Google_Stock_Price_Train.csv')

# %%
train_set.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %% [markdown]
# - **Performing MinMax Scaling over the dataset**

# %%
## Train set
training_set=train_set.iloc[:,1:2].values
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

## Test set
testing_set=train_set.iloc[:,1:2].values
testing_set_scaled = sc.fit_transform(testing_set)

# %%
plt.plot(training_set_scaled)
plt.show()

# %% [markdown]
# - **Spiliting the data into the required timesteps to be fed to sequence models**

# %%
X_train, Y_train, X_test = [], [], []

timesteps = 50
for i in range(timesteps, len(training_set_scaled)):
    X_train.append(training_set_scaled[i-timesteps:i,0])
    Y_train.append(training_set_scaled[i,0])
X_train, Y_train = np.array(X_train), np.array(Y_train)

for i in range(timesteps, len(testing_set_scaled)):
    X_test.append(training_set_scaled[i-timesteps:i,0])
    
X_train, Y_train, X_test = np.array(X_train), np.array(Y_train), np.array(X_test)

# %% [markdown]
# - **Reshaping the data into (instances, timesteps, dimension) shape**

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# ## Functions for Visualisation

# %%
def visualise_train(history):
  sns.set_style("darkgrid")
  train_mse = history.history['mse']
  valid_mse = history.history['val_mse']
  epochs = range(1, len(valid_mse) + 1)

  plt.figure()

  #Train and validation loss

  plt.plot(epochs, train_mse, 'b', label='Training MSE')
  plt.plot(epochs, valid_mse, 'r', label='Validation MSE')
  plt.xlabel('Epoch #')
  plt.ylabel('Loss')
  plt.title('Training and Validation MSE')
  plt.legend()

  plt.show()

# %%
def visualise_test(Y_pred):
  Y_pred = sc.inverse_transform(Y_pred)
  plt.plot(testing_set, color = "red", label = "Real Google Stock Price")
  plt.plot(Y_pred, color = "blue", label = "Predicted Google Stock Price")
  plt.title("Google Stock Price Prediction")
  plt.xlabel("Time")
  plt.ylabel("Google Stock Price")
  plt.legend()
  plt.show()

# %% [markdown]
# ## Simple RNN Model

# %% [markdown]
# - **Creating the SimpleRNN model using SimpleRNN layers from Keras**

# %%
def SimpleRNN():
  regressor = tf.keras.Sequential([
      tf.keras.layers.SimpleRNN(units=50,return_sequences=True,input_shape=(X_train.shape[1], 1)),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.SimpleRNN(units=50,return_sequences=True),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.SimpleRNN(units=50,return_sequences=True),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.SimpleRNN(units=50),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Dense(units=1)
      ])
  regressor.summary()
  regressor.compile(optimizer='adam', loss='mean_squared_error', metrics = [tf.keras.metrics.MeanSquaredError(name='mse')])
  return regressor

# %% [markdown]
# - **Training the Simple RNN Model**

# %%
rnn = SimpleRNN()
history_rnn = rnn.fit(X_train, Y_train, batch_size = 32, epochs = 15, validation_split=0.3, verbose=1)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_20 (SimpleRNN)   (None, 50, 50)            2600
#
#  dropout_40 (Dropout)        (None, 50, 50)            0
#
#  simple_rnn_21 (SimpleRNN)   (None, 50, 50)            5050
#
#  dropout_41 (Dropout)        (None, 50, 50)            0
#
#  simple_rnn_22 (SimpleRNN)   (None, 50, 50)            5050
#
#  dropout_42 (Dropout)        (None, 50, 50)            0
#
#  simple_rnn_23 (SimpleRNN)   (None, 50)                5050
#
#  dropout_43 (Dropout)        (None, 50)                0
#
#  dense_10 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 17,801
# Trainable params: 17,801
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 27/27 [==============================] - 9s 250ms/step - loss: 0.5213 - mse: 0.5213 - val_loss: 0.2118 - val_mse: 0.2118
# Epoch 2/15
# 27/27 [==============================] - 5s 170ms/step - loss: 0.3001 - mse: 0.3001 - val_loss: 0.0448 - val_mse: 0.0448
# Epoch 3/15
# 27/27 [==============================] - 5s 197ms/step - loss: 0.2701 - mse: 0.2701 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 4/15
# 27/27 [==============================] - 5s 192ms/step - loss: 0.2113 - mse: 0.2113 - val_loss: 0.1002 - val_mse: 0.1002
# Epoch 5/15
# 27/27 [==============================] - 7s 271ms/step - loss: 0.1842 - mse: 0.1842 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 6/15
# 27/27 [==============================] - 7s 261ms/step - loss: 0.1386 - mse: 0.1386 - val_loss: 0.0707 - val_mse: 0.0707
# Epoch 7/15
# 27/27 [==============================] - 6s 202ms/step - loss: 0.1120 - mse: 0.1120 - val_loss: 0.0791 - val_mse: 0.0791
# Epoch 8/15
# 27/27 [==============================] - 5s 196ms/step - loss: 0.0868 - mse: 0.0868 - val_loss: 0.0536 - val_mse: 0.0536
# Epoch 9/15
# 27/27 [==============================] - 7s 245ms/step - loss: 0.0677 - mse: 0.0677 - val_loss: 0.0353 - val_mse: 0.0353
# Epoch 10/15
# 27/27 [==============================] - 5s 197ms/step - loss: 0.0629 - mse: 0.0629 - val_loss: 0.0155 - val_mse: 0.0155
# Epoch 11/15
# 27/27 [==============================] - 5s 203ms/step - loss: 0.0533 - mse: 0.0533 - val_loss: 0.0210 - val_mse: 0.0210
# Epoch 12/15
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0555 - mse: 0.0555 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 13/15
# 27/27 [==============================] - 5s 171ms/step - loss: 0.0444 - mse: 0.0444 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 14/15
# 27/27 [==============================] - 5s 190ms/step - loss: 0.0407 - mse: 0.0407 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 15/15
# 27/27 [==============================] - 9s 320ms/step - loss: 0.0384 - mse: 0.0384 - val_loss: 0.0214 - val_mse: 0.0214

# %% [markdown]
# - **Visualising the Training Error**

# %%
visualise_train(history_rnn)

# %% [markdown]
# - **Testing the model**

# %%
Y_pred_rnn = rnn.predict(X_test, verbose = 1)
# Out:
# 38/38 [==============================] - 1s 16ms/step

# %% [markdown]
# - **Visualising the results**

# %%
visualise_test(Y_pred_rnn)

# %% [markdown]
# ## LSTM Model

# %% [markdown]
# - **Creating the LSTM Model**

# %%
def LSTM():
  regressor = tf.keras.Sequential([
      tf.keras.layers.LSTM(units=50,return_sequences=True,input_shape=(X_train.shape[1], 1)),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.LSTM(units=50,return_sequences=True),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.LSTM(units=50,return_sequences=True),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.LSTM(units=50),
      tf.keras.layers.Dropout(0.2),
      tf.keras.layers.Dense(units=1)
      ])
  regressor.summary()
  regressor.compile(optimizer='adam', loss='mean_squared_error', metrics = [tf.keras.metrics.MeanSquaredError(name='mse')])
  return regressor

# %% [markdown]
# - **Training the LSTM Model**

# %%
lstm = LSTM()
history_lstm = lstm.fit(X_train, Y_train, batch_size = 32, epochs = 4, validation_split = 0.3, verbose=1)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_28 (LSTM)              (None, 50, 50)            10400
#
#  dropout_52 (Dropout)        (None, 50, 50)            0
#
#  lstm_29 (LSTM)              (None, 50, 50)            20200
#
#  dropout_53 (Dropout)        (None, 50, 50)            0
#
#  lstm_30 (LSTM)              (None, 50, 50)            20200
#
#  dropout_54 (Dropout)        (None, 50, 50)            0
#
#  lstm_31 (LSTM)              (None, 50)                20200
#
#  dropout_55 (Dropout)        (None, 50)                0
#
#  dense_13 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/4
# 27/27 [==============================] - 7s 64ms/step - loss: 0.0291 - mse: 0.0291 - val_loss: 0.0403 - val_mse: 0.0403
# Epoch 2/4
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 3/4
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 4/4
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0032 - val_mse: 0.0032

# %% [markdown]
# - **Visualising the Training Error**

# %%
visualise_train(history_lstm)

# %% [markdown]
# - **Testing the Model**

# %%
Y_pred_lstm = lstm.predict(X_test, verbose=1)
# Out:
# 38/38 [==============================] - 1s 6ms/step

# %% [markdown]
# - **Visualising the results**

# %%
visualise_test(Y_pred_lstm)

# %% [markdown]
# ## Tabulation of both the models for comparison

# %%
from tabulate import tabulate
table = [['MSE', 'SimpleRNN', 'LSTM'],
         ['Train',history_rnn.history['mse'][-1], history_lstm.history['mse'][-1]],
         ['Test', Y_pred_rnn[1], Y_pred_lstm[1]]
        ]

print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒═══════╤═════════════╤═══════════╕
# │ MSE   │   SimpleRNN │      LSTM │
# ╞═══════╪═════════════╪═══════════╡
# │ Train │  0.0383811  │ 0.0035165 │
# ├───────┼─────────────┼───────────┤
# │ Test  │  0.00873184 │ 0.0677331 │
# ╘═══════╧═════════════╧═══════════╛
